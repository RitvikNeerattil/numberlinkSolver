# %% [markdown]
# # NumberLink Solver Training on Google Colab

# %% [markdown]
# 1. Clone the Repository

# %%
# !git clone --recurse-submodules https://github.com/RitvikNeerattil/numberlinkSolver.git

# %%
# %cd numberlinkSolver

# %% [markdown]
# 2. Install Dependencies

# %%
# !pip install -e ./DeepXube

# %%
# !pip install -r ./NumberLink/requirements.txt

# %% [markdown]
# 3. Verify GPU Availability

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

# %% [markdown]
# 4. Run Training

# %%
# !mkdir -p models/numberlink_v

# %%
# !python DeepXube/examples/train_numberlink.py \\n
    --nnet_dir models/numberlink_v \\n
    --step_max 100 \\n
    --width 7 \\n
    --height 7 \\n
    --num_colors 5 \\n
    --up_procs 2 \\n
    --batch_size 128 \\n
    --max_itrs 10000 \\n
    --device cuda
