# %% [markdown]
# # NumberLink Solver Training on Google Colab

# %% [markdown]
# 1. Clone the Repository, isntall dependencies

# %%
# !git clone --recurse-submodules https://github.com/RitvikNeerattil/numberlinkSolver.git
# %cd numberlinkSolver

# !pip install -e ./DeepXube
# !pip install -e ./NumberLink

# %%
#after restart ^
# %cd numberlinkSolver

# %% [markdown]
# 3. Verify GPU/CPU Availability

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# !lscpu | grep "Model name"
# !lscpu | grep "^CPU(s):"

# %% [markdown]
# 4. Run Training

# %%
# !python DeepXube/examples/train_numberlink.py --nnet_dir models/numberlink_v --step_max 50 --width 7 --height 7 --num_colors 5 --up_procs 12 --up_itrs 10 --up_gen_itrs 10 --up_search_itrs 20 --up_batch_size 64 --batch_size 256 --max_itrs 20000 --device cuda
